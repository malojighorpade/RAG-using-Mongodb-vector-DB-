# %%
import os


os.environ["GOOGLE_API_KEY"] = "AIzaSyDjVZ46EdXFOAv_iPc_oy2prRH8tYjxcKo"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash",temperature=0.5)
model="models/gemini-embedding-001"
embedings=GoogleGenerativeAIEmbeddings(model=model)

# embeddings=GoogleGenerativeAIEmbeddings(model=model)
def get_embedding(text):
     return embedings.embed_query(text)

# %%
from google import genai
import os

# correct way
client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

models = client.models.list()

for m in models:
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# ...

# %%
embed=get_embedding("keyboard typeing")
embed[:9]
# Out:
# [-0.023864478,
#  -0.010079178,
#  0.014600256,
#  -0.035114132,
#  -0.020854007,
#  0.0165432,
#  0.0049582887,
#  0.00890655,
#  0.005544162]

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
load=PyPDFLoader("https://investors.mongodb.com/node/12236/pdf")
data=load.load()
text_spliter=RecursiveCharacterTextSplitter(chunk_size=400,chunk_overlap=20)
text=text_spliter.split_documents(data)

# %%
text
# Out:
# [Document(metadata={'producer': 'West Corporation using ABCpdf', 'creator': 'PyPDF', 'creationdate': '2024-05-30T20:06:12+00:00', 'title': 'MongoDB, Inc. Announces First Quarter Fiscal 2025 Financial Results', 'source': 'https://investors.mongodb.com/node/12236/pdf', 'total_pages': 8, 'page': 0, 'page_label': '1'}, page_content='MongoDB, Inc. Announces First Quarter Fiscal 2025 Financial Results\nMay 30, 2024\nFirst Quarter Fiscal 2025 Total Revenue of $450.6 million, up 22% Year-over-Year\nContinued Strong Customer Growth with Over 49,200 Customers as of April 30, 2024\nMongoDB Atlas Revenue up 32% Year-over-Year; 70% of Total Q1 Revenue'),
# ...

# %%
len(data)
# Out:
# 8

# %%
docs_to_insert=[
    {
        "text":doc.page_content,
        "embedings":get_embedding(doc.page_content)
    }for doc in text
]

# %%
docs_to_insert
# Out:
# [{'text': 'MongoDB, Inc. Announces First Quarter Fiscal 2025 Financial Results\nMay 30, 2024\nFirst Quarter Fiscal 2025 Total Revenue of $450.6 million, up 22% Year-over-Year\nContinued Strong Customer Growth with Over 49,200 Customers as of April 30, 2024\nMongoDB Atlas Revenue up 32% Year-over-Year; 70% of Total Q1 Revenue',
#   'embedings': [-0.027504634,
#    0.01827896,
#    -0.00640047,
#    -0.0922297,
#    -0.0034582585,
#    0.027722841,
#    0.021760482,
#    -0.012786122,
#    -0.031444773,
#    0.04272564,
#    0.00446207,
#    -0.005696556,
#    0.012480129,
#    -0.014734025,
#    0.11720198,
#    -0.0012443359,
#    0.013407363,
#    -0.016932404,
#    -0.0009673481,
#    -0.013949263,
#    -0.024083724,
#    0.003230869,
#    0.0008372245,
#    -0.010232543,
#    -0.011773399,
#    -0.004680616,
#    0.0047065765,
#    0.001529042,
#    0.030352505,
#    -0.0047439868,
#    -0.004748192,
#    -0.03420273,
#    0.02168162,
#    0.0009172202,
#    -0.00041894676,
# ...

# %%
from pymongo import MongoClient
client=MongoClient("mongodb+srv://malojighorpade07_db_user:5Z222Cnalb6LEg7H@rag.wdqhzbz.mongodb.net/?appName=RAG")
collection=client["rag_data"]["rag_embeddings"]
result=collection.insert_many(docs_to_insert)
result
# Out:
# InsertManyResult([ObjectId('69bd17ee39d7cccc74738ca4'), ObjectId('69bd17ee39d7cccc74738ca5'), ObjectId('69bd17ee39d7cccc74738ca6'), ObjectId('69bd17ee39d7cccc74738ca7'), ObjectId('69bd17ee39d7cccc74738ca8'), ObjectId('69bd17ee39d7cccc74738ca9'), ObjectId('69bd17ee39d7cccc74738caa'), ObjectId('69bd17ee39d7cccc74738cab'), ObjectId('69bd17ee39d7cccc74738cac'), ObjectId('69bd17ee39d7cccc74738cad'), ObjectId('69bd17ee39d7cccc74738cae'), ObjectId('69bd17ee39d7cccc74738caf'), ObjectId('69bd17ee39d7cccc74738cb0'), ObjectId('69bd17ee39d7cccc74738cb1'), ObjectId('69bd17ee39d7cccc74738cb2'), ObjectId('69bd17ee39d7cccc74738cb3'), ObjectId('69bd17ee39d7cccc74738cb4'), ObjectId('69bd17ee39d7cccc74738cb5'), ObjectId('69bd17ee39d7cccc74738cb6'), ObjectId('69bd17ee39d7cccc74738cb7'), ObjectId('69bd17ee39d7cccc74738cb8'), ObjectId('69bd17ee39d7cccc74738cb9'), ObjectId('69bd17ee39d7cccc74738cba'), ObjectId('69bd17ee39d7cccc74738cbb'), ObjectId('69bd17ee39d7cccc74738cbc'), ObjectId('69bd17ee39d7cccc7473
# ...

# %%
from pymongo.operations import SearchIndexModel
import time
index_name="vector_indexes"
search_index_model=SearchIndexModel(
    definition={
        "fields": [
    {
      "type": "vector",
      "path": "embedding",
      "numDimensions": 3072,
      "similarity": "cosine"
    }
  ]
    },
    name=index_name,
    type="vectorSearch"
)
collection.create_search_index(model=search_index_model)
# Out:
# 'vector_indexes'

# %%
print("polling to check if the index is ready ")
predicate=None
if predicate is None:
    predicate = lambda index:index.get("queryable") is True
while True:
    indices=list(collection.list_search_indexes(index_name))
    if len(indices) and predicate(indices[0]):
        break
    time.sleep(5)
print(index_name+"is ready")
# Out:
# polling to check if the index is ready
# vector_indexesis ready

# %%
query_embedding=get_embedding("Ai technolgy")
collection.rag_embeddings.aggregate([
    {
        "$vectorSearch":{
            "index":"vector_indexes",
            "path":"embedding",
            "queryVector":query_embedding,
            "numCandidates":3072,
            "limit":5
        }
    }

])

# %%
def get_query_result(query):
    query_embedding = get_embedding(query)

    pipeline = [
        {
            "$vectorSearch": {
                "index": "vector_indexes",
                "path": "embedding",
                "queryVector": query_embedding,
                "numCandidates": 500,
                "limit": 5
            }
        },
        {
            "$project": {
                "_id": 0,
                "text": 1,
                "score": {"$meta": "vectorSearchScore"}
            }
        }
    ]

    results = list(collection.aggregate(pipeline))

    # ✅ Remove duplicates
    unique_texts = {}
    for doc in results:
        unique_texts[doc["text"]] = doc

    return list(unique_texts.values())

# %%
get_query_result("mongodb annual result")
# Out:
# Query: mongodb annual result
# Embedding length: 3072
# [{'text': 'NEW YORK, May 30, 2024 /PRNewswire/ -- MongoDB, Inc. (NASDAQ: MDB) today announced its financial results for the first quarter ended April 30,\n2024.\n\xa0\n  \xa0\n"MongoDB\'s delivered solid first quarter results, highlighted by 32% Atlas revenue growth. At the same time, we had a slower than expected start to',
#   'score': 0.8687536716461182},
#  {'text': 'NEW YORK, May 30, 2024 /PRNewswire/ -- MongoDB, Inc. (NASDAQ: MDB) today announced its financial results for the first quarter ended April 30,\n2024.\n\xa0\n  \xa0\n"MongoDB\'s delivered solid first quarter results, highlighted by 32% Atlas revenue growth. At the same time, we had a slower than expected start to',
#   'score': 0.8687536716461182},
# ...

# %%
print(collection.count_documents({}))
# Out:
# 264

# %%
doc = collection.find_one()
print(doc)
# Out:
# {'_id': ObjectId('69bab8b7fb4ae99bf1a52c70'), 'text': 'MongoDB, Inc. Announces First Quarter Fiscal 2025 Financial Results\nMay 30, 2024\nFirst Quarter Fiscal 2025 Total Revenue of $450.6 million, up 22% Year-over-Year\nContinued Strong Customer Growth with Over 49,200 Customers as of April 30, 2024\nMongoDB Atlas Revenue up 32% Year-over-Year; 70% of Total Q1 Revenue', 'embedding': [-0.027504634, 0.01827896, -0.00640047, -0.0922297, -0.0034582585, 0.027722841, 0.021760482, -0.012786122, -0.031444773, 0.04272564, 0.00446207, -0.005696556, 0.012480129, -0.014734025, 0.11720198, -0.0012443359, 0.013407363, -0.016932404, -0.0009673481, -0.013949263, -0.024083724, 0.003230869, 0.0008372245, -0.010232543, -0.011773399, -0.004680616, 0.0047065765, 0.001529042, 0.030352505, -0.0047439868, -0.004748192, -0.03420273, 0.02168162, 0.0009172202, -0.00041894676, 0.013797669, 0.018960517, 0.0017327509, 0.0063527357, 0.010138164, -0.014173844, 0.013618424, -0.0026363654, -0.020155074, -0.002943958,
# ...

# %%
print(len(query_embedding))
# Out:
# 3072

# %%
doc = collection.find_one()
print(len(doc["embedding"]))
# Out:
# 3072

# %%
doc = collection.find_one()
print(doc.keys())
# Out:
# dict_keys(['_id', 'text', 'embedding'])

# %%
def generate_answer(query):
    context_docs = get_query_result(query)

    if not context_docs:
        return "No relevant data found."

    context_string = "\n\n".join([doc["text"] for doc in context_docs])

    prompt = f"""
        You are an AI assistant.

        Use ONLY the context below to answer the question.

        Give a detailed answer (5-6 lines).

        Context:
        {context_string}

        Question:
        {query}

        Answer:
"""

    response = llm.invoke(prompt)
    return response.content

# %%
results=generate_answer("what is MongoDB latest AI announcement")
result
# Out:
# InsertManyResult([ObjectId('69bd17ee39d7cccc74738ca4'), ObjectId('69bd17ee39d7cccc74738ca5'), ObjectId('69bd17ee39d7cccc74738ca6'), ObjectId('69bd17ee39d7cccc74738ca7'), ObjectId('69bd17ee39d7cccc74738ca8'), ObjectId('69bd17ee39d7cccc74738ca9'), ObjectId('69bd17ee39d7cccc74738caa'), ObjectId('69bd17ee39d7cccc74738cab'), ObjectId('69bd17ee39d7cccc74738cac'), ObjectId('69bd17ee39d7cccc74738cad'), ObjectId('69bd17ee39d7cccc74738cae'), ObjectId('69bd17ee39d7cccc74738caf'), ObjectId('69bd17ee39d7cccc74738cb0'), ObjectId('69bd17ee39d7cccc74738cb1'), ObjectId('69bd17ee39d7cccc74738cb2'), ObjectId('69bd17ee39d7cccc74738cb3'), ObjectId('69bd17ee39d7cccc74738cb4'), ObjectId('69bd17ee39d7cccc74738cb5'), ObjectId('69bd17ee39d7cccc74738cb6'), ObjectId('69bd17ee39d7cccc74738cb7'), ObjectId('69bd17ee39d7cccc74738cb8'), ObjectId('69bd17ee39d7cccc74738cb9'), ObjectId('69bd17ee39d7cccc74738cba'), ObjectId('69bd17ee39d7cccc74738cbb'), ObjectId('69bd17ee39d7cccc74738cbc'), ObjectId('69bd17ee39d7cccc7473
# ...

# %%
print(generate_answer("What is MongoDB latest AI announcement?"))
# Out:
# MongoDB's latest AI announcement is the MongoDB AI Applications Program (MAAP). This initiative aims to further expand its AI ecosystem, recognizing a significant opportunity to attract more customers and modernize legacy workloads. AI has emerged as a crucial catalyst for updating existing applications. MongoDB's document-based architecture is especially well-suited for handling the diverse and large-scale data demands of AI-powered applications. The company is confident it will be a substantial beneficiary of this upcoming wave of application development.
